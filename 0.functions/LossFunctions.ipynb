# %% [markdown]
# ## Loss Functions in DeepLearning
# Loss Function calculates how much error between predicted target and actual target.

# %% [markdown]
# ## L1 Loss
# Creates a criterion that measures the mean absolute error (MAE) between each element in the input x x and target y y .
